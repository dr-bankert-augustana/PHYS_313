# %% [markdown]
# <a href="https://colab.research.google.com/github/dr-bankert-augustana/PHYS_313/blob/main/Homework_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <a name="Notebook-Start"></a>
#
# ---
#
# <font size = 7> <b> PHYS 313 Homework 3 </b> </font>
#
# ---

# %% [markdown]
# <font size = 5> <b> Notebook Index </b> </font>
#
# 1. [Problem 1](#Problem-1)
#
# 2. [Problem 2](#Problem-2)
#
# 3. [Problem 3](#Problem-3)
#
# 4. [Problem 4](#Problem-4)
#
# 5. [Problem 5](#Problem-5)
# $
# \newcommand{\lsum}{\displaystyle \sum\limits_{i=1}^{N}}
# \newcommand{\parens}[1]{\left(#1\right)}
# \newcommand{\dsfrac}[2]{\displaystyle\frac{#1}{#2}}
# \newcommand{\dpfrac}[2]{\displaystyle\parens{\frac{#1}{#2}}}
# \newcommand{\parderiv}[2]{\dsfrac{\partial #1}{\partial #2}}
# \newcommand{\spc}{\hspace{0.1 pc}}
# \newcommand{\ra}{\Rightarrow}
# \newcommand{\of}[1]{{\scriptsize (#1)}}
# \newcommand{\rule}{\Huge \hspace{-0.2 pc} \displaystyle\frac{\hspace{20 pc}}{\hspace{20 pc}}}
# \newcommand{\mps}{\spc \frac{\textrm{m}}{\textrm{s}}}
# \newcommand{\mpss}{\spc \frac{\textrm{m}}{\textrm{s}^2}}
# $

# %% [markdown]
# <a name="Problem-1"></a>
#
# ---
#
# <font size = 6> <b> Problem 1 </b> </font>
#
# ---

# %% [markdown]
# Water is to be boiled at sea level in a 30-cm-diameter
# stainless steel pan placed on top of a 3-kW electric burner.
# If 60 percent of the heat generated by the burner is transferred to the water during boiling, determine the rate of evap-
# oration of water.

# %%
# Please feel free to use Python to help with this problem.

# %% [markdown]
# <b>Your Answer Here</b>

# %% [markdown]
# [Return to Top](#Notebook-Start)

# %% [markdown]
# <a name="Problem-2"></a>
#
# ---
#
# <font size = 6> <b> Problem 2 </b> </font>
#
# ---

# %% [markdown]
# 10-kg of R-134a at 300 kPa fills a rigid container
# whose volume is 14 L. Determine the temperature and total
# enthalpy in the container. The container is now heated until
# the pressure is 600 kPa. Determine the temperature and total
# enthalpy when the heating is completed.

# %%
# Please feel free to use Python to help with this problem.

# %% [markdown]
# <b>Your Answer Here</b>

# %% [markdown]
# [Return to Top](#Notebook-Start)

# %% [markdown]
# <a name="Problem-3"></a>
#
# ---
#
# <font size = 6> <b> Problem 3 </b> </font>
#
# ---

# %% [markdown]
# A piston-cylinder device initially contains 1.4-kg saturated liquid water at 200 degree C. Now heat is transferred to the
# water until the volume quadruples and the cylinder contains saturated vapor only. Determine (a) the volume of the tank,
# (b) the final temperature and pressure, and (c) the internal
# energy change of the water.

# %%
# Please feel free to use Python to help with this problem.

# %% [markdown]
# <b>Your Answer Here</b>

# %% [markdown]
# [Return to Top](#Notebook-Start)

# %% [markdown]
# <a name="Problem-4"></a>
#
# ---
#
# <font size = 6> <b> Problem 4 </b> </font>
#
# ---

# %% [markdown]
# A 1-m3 tank containing air at 10 degrees C and 350 kPa is
# connected through a valve to another tank containing 3 kg
# of air at 35 degree C and 200 kPa. Now the valve is opened, and
# the entire system is allowed to reach thermal equilibrium
# with the surroundings, which are at 20 degree C. Determine the volume of the second tank and the final equilibrium pressure of
# air.

# %%
# Please feel free to use Python to help with this problem.

# %% [markdown]
# <b>Your Answer Here</b>

# %% [markdown]
# [Return to Top](#Notebook-Start)

# %% [markdown]
# <a name="Problem-5"></a>
#
# ---
#
# <font size = 6> <b> Problem 5 </b> </font>
#
# ---

# %% [markdown]
# Saturated water vapor at 350 degree C is heated at constant
# pressure until its volume has doubled. Determine the final
# temperature using the ideal gas equation of state, the compressibility charts, and the steam tables.

# %%
# Please feel free to use Python to help with this problem.

# %% [markdown]
# <b>Your Answer Here</b>

# %% [markdown]
# [Return to Top](#Notebook-Start)
#
# ---
